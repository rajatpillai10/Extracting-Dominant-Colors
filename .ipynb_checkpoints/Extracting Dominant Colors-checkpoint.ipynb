# %% [markdown]
# ### Dominant Color Extraction for Image Segmentation

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
im =  cv2.imread('balloon.jpg') #Reads an image into BGR Format
im = cv2.cvtColor(im,cv2.COLOR_BGR2RGB)
original_shape = im.shape
print(im.shape)
# Out:
# (1600, 1321, 3)

# %%
plt.figure(figsize=(8,8))
plt.imshow(im) 
plt.axis("off")
plt.show()

# %%
all_pixels  = im.reshape((-1,3))
print(all_pixels.shape)
# Out:
# (2113600, 3)

# %%
from sklearn.cluster import KMeans

# %%
dominant_colors = 4

km = KMeans(n_clusters=dominant_colors)
km.fit(all_pixels)
# Out:
# KMeans(n_clusters=4)

# %%
centers = km.cluster_centers_
centers = np.array(centers,dtype='uint8')

# %%
print(centers)
# Out:
# [[107 146 219]
#  [154  40   7]
#  [151 167 203]
#  [ 49  40  51]]

# %%
i = 1
plt.figure(0,figsize=(8,2))
colors = []

for each_col in centers:
    plt.subplot(1,4,i)
    plt.axis("off")
    i+=1
    
    colors.append(each_col)
    
    #Color Swatch
    a = np.zeros((150,150,3),dtype='uint8')
    a[:,:] = each_col
    plt.imshow(a)
    
plt.show()

# %% [markdown]
# ### Segmenting Original Image

# %%
new_img = np.zeros((1600 * 1321,3),dtype='uint8')
print(new_img.shape)
# Out:
# (2113600, 3)

# %%
colors
# Out:
# [array([107, 146, 219], dtype=uint8),
#  array([154,  40,   7], dtype=uint8),
#  array([151, 167, 203], dtype=uint8),
#  array([49, 40, 51], dtype=uint8)]

# %%
km.labels_
# Out:
# array([0, 0, 0, ..., 2, 2, 2])

# %%
for ix in range(new_img.shape[0]):
    new_img[ix] = colors[km.labels_[ix]]
    
new_img = new_img.reshape((original_shape))
plt.figure(figsize=(8,8))
plt.imshow(new_img)
plt.axis("off")
plt.show()
